# %% [markdown]
#  ## Assigmnemt-Class Marks
#  ## J.Sravani
#  ## 2211CS010235

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Import the pandas and define the variable import the data set

# %%
df= pd.read_csv("class_marks.csv")
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     NaN    NaN
# 2     NaN    NaN
# 3     2.0    NaN
# ...

# %% [markdown]
# # Showing the data set

# %%
df.head()
# Out:
#    Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0     37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1     32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2     33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3     24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4     36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
#
#    Q6aM4  Q6bM6
# 0    4.0    6.0
# 1    NaN    NaN
# 2    NaN    NaN
# 3    2.0    NaN
# 4    NaN    NaN

# %% [markdown]
# # shows the first 5 rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Total   86 non-null     int64
#  1   Q1aM4   85 non-null     float64
#  2   Q1bM6   73 non-null     float64
#  3   Q2aM6   72 non-null     float64
#  4   Q2bM4   75 non-null     float64
#  5   Q3aM5   52 non-null     float64
#  6   Q3bM5   51 non-null     float64
#  7   Q4aM3   32 non-null     float64
#  8   Q4bM7   26 non-null     float64
#  9   Q5M10   56 non-null     float64
#  10  Q6aM4   33 non-null     float64
#  11  Q6bM6   28 non-null     float64
# dtypes: float64(11), int64(1)
# memory usage: 8.2 KB

# %% [markdown]
# # function in pandas provides a concise summary of a DataFrame, including its shape, column names, non-null counts, data types, and memory usage.

# %%
df.isnull()
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0   False  False  False  False  False  False  False   True  False  False
# 1   False  False  False  False  False   True   True  False  False  False
# 2   False  False  False  False  False  False  False   True   True  False
# 3   False  False  False  False  False  False  False   True   True   True
# 4   False  False  False  False  False  False  False   True   True  False
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81  False  False  False  False  False  False  False   True   True   True
# 82  False  False  False  False  False   True   True   True   True  False
# 83  False  False  False  False  False   True   True   True   True  False
# 84  False  False   True  False  False  False  False   True   True  False
# 85  False  False  False   True   True   True   True  False  False  False
#
#     Q6aM4  Q6bM6
# 0   False  False
# 1    True   True
# 2    True   True
# 3   False   True
# ...

# %%
df.tail()
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 81    4.0    6.0
# 82    3.0    5.0
# 83    4.0    6.0
# 84    NaN    NaN
# 85    1.0    4.0

# %% [markdown]
# # shows the last 5 rows

# %%
df.shape
# Out:
# (86, 12)

# %% [markdown]
# # It is an attribute in pandas returns a tuple representing the number of rows and columns.

# %%
df.loc[15:20]
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 15     32    3.0    NaN    2.0    1.0    5.0    5.0    3.0    7.0    NaN
# 16     30    4.0    NaN    6.0    4.0    5.0    2.0    NaN    NaN    8.0
# 17     36    3.0    4.0    6.0    4.0    NaN    NaN    NaN    NaN    9.0
# 18     24    3.0    3.0    5.0    3.0    NaN    NaN    2.0    1.0    7.0
# 19     26    3.0    NaN    6.0    4.0    NaN    2.0    2.0    1.0    7.0
# 20     29    2.0    6.0    2.0    2.0    5.0    5.0    NaN    NaN    7.0
#
#     Q6aM4  Q6bM6
# 15    4.0    6.0
# 16    NaN    NaN
# 17    4.0    6.0
# 18    NaN    NaN
# 19    3.0    NaN
# 20    NaN    NaN

# %% [markdown]
# # selects rows with index labels from 15 to 20.

# %%
columns_to_drop = [col for col in  df.columns]

# %%
columns_to_drop
# Out:
# ['Total',
#  'Q1aM4',
#  'Q1bM6',
#  'Q2aM6',
#  'Q2bM4',
#  'Q3aM5',
#  'Q3bM5',
#  'Q4aM3',
#  'Q4bM7',
#  'Q5M10',
#  'Q6aM4',
#  'Q6bM6']

# %%
df["2Q"]=df["Q1aM4"]+df["Q1bM6"]
df["5Q"]=df["Q2aM6"]+df["Q2bM4"]

# %%
df.drop("Q5M10",axis=1,inplace=True)
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q6aM4  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    4.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    NaN
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    NaN
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    2.0
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN    NaN
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    4.0
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    3.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    4.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    NaN
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    1.0
#
#     Q6bM6    2Q    5Q
# 0     6.0   9.0  10.0
# 1     NaN   7.0   7.0
# ...

# %% [markdown]
# # modifying it in place

# %%
df.isnull().sum()
# Out:
# Total     0
# Q1aM4     1
# Q1bM6    13
# Q2aM6    14
# Q2bM4    11
# Q3aM5    34
# Q3bM5    35
# Q4aM3    54
# Q4bM7    60
# Q6aM4    53
# Q6bM6    58
# 2Q       13
# 5Q       16
# dtype: int64

# %% [markdown]
# # Returns the count of missing values in each column of the Data set

# %%
 df.fillna(0)
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q6aM4  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    0.0    5.0    4.0
# 1      32    4.0    3.0    4.0    3.0    0.0    0.0    3.0    6.0    0.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    0.0    0.0    0.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    0.0    0.0    2.0
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    0.0    0.0    0.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    0.0    0.0    4.0
# 82     27    2.0    2.0    5.0    3.0    0.0    0.0    0.0    0.0    3.0
# 83     37    4.0    6.0    6.0    2.0    0.0    0.0    0.0    0.0    4.0
# 84     28    4.0    0.0    5.0    4.0    5.0    4.0    0.0    0.0    0.0
# 85     29    4.0    6.0    0.0    0.0    0.0    0.0    3.0    5.0    1.0
#
#     Q6bM6    2Q    5Q
# 0     6.0   9.0  10.0
# 1     0.0   7.0   7.0
# ...

# %% [markdown]
# # Replaces all missing values in with 0.

# %%
df.fillna(0,inplace=True)

# %%
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q6aM4  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    0.0    5.0    4.0
# 1      32    4.0    3.0    4.0    3.0    0.0    0.0    3.0    6.0    0.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    0.0    0.0    0.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    0.0    0.0    2.0
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    0.0    0.0    0.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    0.0    0.0    4.0
# 82     27    2.0    2.0    5.0    3.0    0.0    0.0    0.0    0.0    3.0
# 83     37    4.0    6.0    6.0    2.0    0.0    0.0    0.0    0.0    4.0
# 84     28    4.0    0.0    5.0    4.0    5.0    4.0    0.0    0.0    0.0
# 85     29    4.0    6.0    0.0    0.0    0.0    0.0    3.0    5.0    1.0
#
#     Q6bM6    2Q    5Q
# 0     6.0   9.0  10.0
# 1     0.0   7.0   7.0
# ...

# %%
df=df.astype("int64")
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q6aM4  \
# 0      37      4      5      6      4      2      1      0      5      4
# 1      32      4      3      4      3      0      0      3      6      0
# 2      33      4      5      5      1      5      5      0      0      0
# 3      24      4      6      6      3      2      2      0      0      2
# 4      36      3      6      4      4      5      4      0      0      0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32      3      6      3      4      5      3      0      0      4
# 82     27      2      2      5      3      0      0      0      0      3
# 83     37      4      6      6      2      0      0      0      0      4
# 84     28      4      0      5      4      5      4      0      0      0
# 85     29      4      6      0      0      0      0      3      5      1
#
#     Q6bM6  2Q  5Q
# 0       6   9  10
# 1       0   7   7
# 2       0   9   6
# ...

# %% [markdown]
# # Is used to replace specific values in a Dataset or Series with new values.

# %%
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q6aM4  \
# 0      37      4      5      6      4      2      1      0      5      4
# 1      32      4      3      4      3      0      0      3      6      0
# 2      33      4      5      5      1      5      5      0      0      0
# 3      24      4      6      6      3      2      2      0      0      2
# 4      36      3      6      4      4      5      4      0      0      0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32      3      6      3      4      5      3      0      0      4
# 82     27      2      2      5      3      0      0      0      0      3
# 83     37      4      6      6      2      0      0      0      0      4
# 84     28      4      0      5      4      5      4      0      0      0
# 85     29      4      6      0      0      0      0      3      5      1
#
#     Q6bM6  2Q  5Q
# 0       6   9  10
# 1       0   7   7
# 2       0   9   6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Total   86 non-null     int64
#  1   Q1aM4   86 non-null     int64
#  2   Q1bM6   86 non-null     int64
#  3   Q2aM6   86 non-null     int64
#  4   Q2bM4   86 non-null     int64
#  5   Q3aM5   86 non-null     int64
#  6   Q3bM5   86 non-null     int64
#  7   Q4aM3   86 non-null     int64
#  8   Q4bM7   86 non-null     int64
#  9   Q6aM4   86 non-null     int64
#  10  Q6bM6   86 non-null     int64
#  11  2Q      86 non-null     int64
#  12  5Q      86 non-null     int64
# dtypes: int64(13)
# memory usage: 8.9 KB

# %%
DF=df.sort_values("Total",ascending=True)
DF
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q6aM4  \
# 69      3      1      0      1      0      0      0      1      0      0
# 11      8      2      2      0      3      1      0      0      0      0
# 23      9      4      3      0      0      0      0      0      0      1
# 22     14      4      4      5      2      0      0      0      0      0
# 57     17      3      0      0      4      0      0      3      7      4
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 73     40      4      6      0      0      5      5      3      0      4
# 53     40      4      6      6      4      5      5      0      0      0
# 51     40      0      0      6      4      0      0      3      7      0
# 33     40      0      0      6      4      5      5      3      7      4
# 65     40      4      6      6      4      5      5      0      0      0
#
#     Q6bM6  2Q  5Q
# 69      0   0   0
# 11      0   4   0
# 23      1   7   0
# ...

# %%
df[df.Total==40]
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q6aM4  \
# 33     40      0      0      6      4      5      5      3      7      4
# 51     40      0      0      6      4      0      0      3      7      0
# 53     40      4      6      6      4      5      5      0      0      0
# 65     40      4      6      6      4      5      5      0      0      0
# 73     40      4      6      0      0      5      5      3      0      4
#
#     Q6bM6  2Q  5Q
# 33      6   0  10
# 51      0   0  10
# 53      0  10  10
# 65      0  10  10
# 73      6  10   0

# %% [markdown]
# # Returns the number of non-null entries in the Total column of the data.

# %%
df.Total.count
# Out:
# <bound method Series.count of 0     37
# 1     32
# 2     33
# 3     24
# 4     36
#       ..
# 81    32
# 82    27
# 83    37
# 84    28
# 85    29
# Name: Total, Length: 86, dtype: int64>

# %% [markdown]
# # Returns the sum of all values in the Total column of the data.

# %%
df.Total.sum()
# Out:
# 2525

# %%
df.fillna(0)
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q6aM4  \
# 0      37      4      5      6      4      2      1      0      5      4
# 1      32      4      3      4      3      0      0      3      6      0
# 2      33      4      5      5      1      5      5      0      0      0
# 3      24      4      6      6      3      2      2      0      0      2
# 4      36      3      6      4      4      5      4      0      0      0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32      3      6      3      4      5      3      0      0      4
# 82     27      2      2      5      3      0      0      0      0      3
# 83     37      4      6      6      2      0      0      0      0      4
# 84     28      4      0      5      4      5      4      0      0      0
# 85     29      4      6      0      0      0      0      3      5      1
#
#     Q6bM6  2Q  5Q
# 0       6   9  10
# 1       0   7   7
# 2       0   9   6
# ...

# %% [markdown]
# # Fills missing values with 0, filters rows where Q4 > 0, and counts the number of non-null values in the Q4 column.

# %%
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['Total', 'Q1aM4', 'Q1bM6', 'Q2aM6', 'Q2bM4', 'Q3aM5', 'Q3bM5', 'Q4aM3',
#        'Q4bM7', 'Q6aM4', 'Q6bM6', '2Q', '5Q'],
#       dtype='object')

# %%
df.plot()
plt.show()

# %% [markdown]
# Prints the column names of the Data.

# %%
a=df.loc[(df['Total'] >= 15) & (df['Total'] <= 20)]
a=a.reset_index()
a
# Out:
#    index  Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  \
# 0      5     20      4      6      6      4      0      0      0      0
# 1     30     20      4      4      4      4      5      0      0      0
# 2     34     19      2      3      3      1      2      3      0      0
# 3     57     17      3      0      0      4      0      0      3      7
# 4     60     20      2      5      3      2      0      0      0      0
# 5     63     18      4      0      4      2      0      0      0      0
# 6     68     20      4      6      6      4      0      0      0      0
# 7     76     17      2      3      4      2      4      2      0      0
#
#    Q6aM4  Q6bM6  2Q  5Q
# 0      0      0  10  10
# 1      0      0   8   8
# 2      0      0   5   4
# 3      4      0   0   0
# 4      0      0   7   5
# 5      0      0   0   6
# 6      0      0  10  10
# 7      0      0   5   6

# %% [markdown]
# # Most of the students scored 1 mark and maximum mark is 2, implying that all the students in this range secure  very less marks in Q1

# %%
plt.hist(a["Q1aM4"],color='green',bins=9,edgecolor='black')
plt.xlabel("Marks scored in Q1aM4")
plt.ylabel("No.of students")
plt.title("Histogram of Q1aM4")
# Out:
# Text(0.5, 1.0, 'Histogram of Q1aM4')

# %% [markdown]
# # Most of the students scored 1bM6 mark and maximum mark is 6, implying that all the students in this range secure  very less marks in Q1bM6

# %%
df['Q1']=a['Q1aM4']+df["Q1bM6"]
plt.hist(df['Q1'],color='yellow',edgecolor='black',bins=9)
plt.xlabel("Marks scored in Q1")
plt.ylabel("No.of students")
plt.title("Histogram of Q1")
# Out:
# Text(0.5, 1.0, 'Histogram of Q1')

# %% [markdown]
# Most of the students scored 1 mark and maximum mark is 10, implying that all the students in this range secure  very less marks in Q1aM4 and Q1aM4

# %%
plt.hist(a["Q2bM4"],color='green',bins=8,edgecolor='black')
plt.xlabel("Marks scored in Q2")
plt.ylabel("No.of students")
plt.title("Histogram of Q2")
# Out:
# Text(0.5, 1.0, 'Histogram of Q2')

# %% [markdown]
# Very few students got high marks in Q2 and that's only 4, so overall performance in Q2 is not upto the mark Q2abM4

# %% [markdown]
# Only one student got 3 marks whereas others scored  below 2 marks, implying very less marks are secured Q3 overall

# %%
plt.hist(df["Q3aM5"],color='brown',bins=16,edgecolor='black')
plt.xlabel("Marks scored in Q3")
plt.ylabel("No.of students")
plt.title("Histogram of Q3")
# Out:
# Text(0.5, 1.0, 'Histogram of Q3')

# %% [markdown]
# Only one student got 3 marks whereas others scored  below 2 marks, implying very less marks are secured Q3aM5 overall

# %%
plt.hist(df["Q3bM5"],color='black',bins=18,edgecolor='black')
plt.xlabel("Marks scored in Q3")
plt.ylabel("No.of students")
plt.title("Histogram of Q3")
# Out:
# Text(0.5, 1.0, 'Histogram of Q3')

# %% [markdown]
# Only one student got 3 marks whereas others scored  below 2 marks, implying very less marks are secured Q3bM5 overall

# %%
df['Q3']=df['Q3aM5']+df["Q3bM5"]
plt.hist(df["Q3"],color='blue',bins=10,edgecolor='black')
plt.xlabel("Marks scored in Q3")
plt.ylabel("No.of students")
plt.title("Histogram of Q3")
# Out:
# Text(0.5, 1.0, 'Histogram of Q3')

# %% [markdown]
# Only one student got 3 marks whereas others scored  below 2 and 3 marks are same, implying very less marks are secured Q3aM5 overall

# %% [markdown]
# Many of these students who attempted Q4 got less  marks and maximum mark is also just two only

# %%
plt.hist(df["Q4aM3"],color='red',bins=20,edgecolor='black')
plt.xlabel("Marks scored in Q4")
plt.ylabel("No.of students")
plt.title("Histogram of Q4")
# Out:
# Text(0.5, 1.0, 'Histogram of Q4')

# %% [markdown]
# Many of these students who attempted Q4 got less  marks and maximum mark is also just two only 3 in Q4aM3

# %%
plt.hist(df["Q4bM7"],color='red',bins=18,edgecolor='black')
plt.xlabel("Marks scored in Q4")
plt.ylabel("No.of students")
plt.title("Histogram of Q4")
# Out:
# Text(0.5, 1.0, 'Histogram of Q4')

# %% [markdown]
# Most of the students scored 1 mark and maximum mark  is 2, implying that all the students in this range secure
#  very less marks in Q1

# %%
a2=df.groupby('Q2')['Total']
a2.hist(color='yellow',figsize=[4,6],grid=False,bins=6)
plt.title("Histogram of students who scored 15-20 Total Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q2")
plt.show()

# %% [markdown]
# Very few students got high marks in Q2 and that's only  2, so overall performance in Q2 is not upto th
#  markQ1

# %%
a6=df.groupby('Q6aM4')['Total']
a6.hist(color='orange',figsize=[8,8],grid=False,bins=8)
plt.title("Histogram of students who scored 15-20 Total Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q6")
plt.show()

# %% [markdown]
# The maximum mark scored in this question is 4 marks, meaning the performance of students in this range remains bad as well.

# %%
b.plot.scatter(x='Q2',y='Total',color='red',s=25)
plt.title("20-25 Marks ANALYSIS")
plt.show()

# %% [markdown]
# Some students have not attempted this question  whereas those who have attempted scored mark between 7 and 10 overall. Maximum mark is 10 scored
#  by three students.s

# %%
b.plot.scatter(x='Q3',y='Total',color='green',s=40)
plt.title("20-25 Marks ANALYSIS")
plt.show()

# %% [markdown]
# Three students haven't attempted the question and most of them who attempted scored 4-7 marks and maximum mark is 10 scored by three students.

# %%
b.plot.scatter(x='Q4',y='Total',color='green',s=40)
plt.title("20-25 Marks ANALYSIS")
plt.show()

# %% [markdown]
# Most of the students in this range haven't attempted 2this question, others got 2-4 marks and maximum mark  is 10 by one student.

# %%
b.plot.scatter(x='Q6aM4',y='Total',color='green',s=40)
plt.title("20-25 Marks ANALYSIS")
plt.show()

# %% [markdown]
# Majority of the students who attempted scored marks between 5 and 9, also some scored zero, meaning five students left the question unattempted

# %%
c.boxplot(by='Q2', column =['Total'], grid = False,color='blue',figsize=[7,8])
plt.title("25-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Majority of the students who attempted the question in  this range scored marks between 7 and 10
#  The maximum mark is 10 whereas minimum mark
#  0.

# %%
c.boxplot(by='Q3', column =['Total'], grid = False,color='brown',figsize=[5,6])
plt.title("25-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# The minimum mark in this question is 0 and maximum  mark is 10
#  Most of the students have secured marks between
#  and 9

# %%
c.boxplot(by='Q4', column =['Total'], grid = False,color='blue',figsize=[5,6])
plt.title("25-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# No student in this range secured full mark for this question.Minimum mark is 0 and the ones who attempted secured low marks.

# %%
c.boxplot(by='Q6aM4', column =['Total'], grid = False,color='orange',figsize=[7,9])
plt.title("25-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# It can be observed that many students scored marks between 4 and 9, the minimum mark remains 0 and none of the students scored full marks in thi question.

# %%
d=df.loc[(df['Total']>=30) & (df['Total']<=45)]
d=d.reset_index()
d
# Out:
#     index  Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  \
# 0       0     37      4      5      6      4      2      1      0      5
# 1       1     32      4      3      4      3      0      0      3      6
# 2       2     33      4      5      5      1      5      5      0      0
# 3       4     36      3      6      4      4      5      4      0      0
# 4       7     34      4      6      6      4      0      0      2      0
# 5       9     35      2      4      5      4      5      5      0      0
# 6      10     37      3      5      6      4      0      0      3      6
# 7      12     34      4      4      5      3      2      2      2      1
# 8      13     32      3      3      6      4      3      5      0      0
# 9      14     30      4      6      6      2      4      5      3      0
# 10     15     32      3      0      2      1      5      5      3      7
# 11     16     30      4      0      6      4      5      2      0      0
# ...

# %% [markdown]
# Total marks 30-45 is filtered from the data set

# %%
df['Q2'].plot(kind='pie',subplots=True,figsize=(8,10))
plt.title("Pie Chart of Q2")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Q2')

# %% [markdown]
# From the above pie chart we can deduce that most of  the students who attempted the question scored mark
#  between 4 and 7, the minimum mark is 0

# %%
df["Q1"].plot(kind='pie',subplots=True,figsize=(8,10))
plt.title("Pie Chart of Q1")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Q1')

# %% [markdown]
# From the above pie chart we can deduce that most of  the students who attempted the question scored mark
#  betwee1 4 an68 7, the minimum mark is 0
