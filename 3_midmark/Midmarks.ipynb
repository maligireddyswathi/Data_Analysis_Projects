# %% [markdown]
# ## Assigmnemt-Mid Marks
# ## J.sravani
# ## 2211CS010235

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_excel("MIDMARKS.xlsx")
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     601 non-null    float64
#  1   SECTION  691 non-null    object
#  2   DV       716 non-null    object
#  3   M-II     716 non-null    object
#  4   PP       716 non-null    object
#  5   BEEE     716 non-null    object
#  6   FL       715 non-null    object
#  7   FIMS     716 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 45.0+ KB

# %%
df.DV.value_counts()
# Out:
# DV
# 20    103
# 17     79
# 16     74
# 18     69
# 15     63
# 19     60
# 11     43
# 12     41
# 14     41
# 13     30
# 10     26
# 9      20
# 6      12
# 5      11
# 8      11
# A      10
# 7       8
# 2       6
# 4       4
# 1       3
# 3       1
# MP      1
# Name: count, dtype: int64

# %%
df.fillna(0)
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   0.0    ZETA  19    8   8   19  17   18
# 714   0.0    ZETA  12    1   7   10  20    8
# 715   0.0    ZETA  17    6  14   14  17   18
# 716   0.0    ZETA  12    1   6    7  15   12
# 717   0.0    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df.value_counts()
# Out:
# S.NO   SECTION  DV  M-II  PP  BEEE  FL  FIMS
# 1.0    ALPHA    12  0     17  9     19  15      1
# 396.0  GAMMA    A   AB    6   7     13  A       1
# 398.0  GAMMA    11  4     7   12    13  15      1
# 399.0  GAMMA    5   3     3   2     10  9       1
# 400.0  GAMMA    20  18    MP  19    18  17      1
#                                                ..
# 202.0  DELTA    19  18    20  16    19  19      1
# 203.0  DELTA    18  17    18  11    20  20      1
# 204.0  DELTA    16  20    15  16    10  18      1
# 205.0  DELTA    18  20    18  14    15  20      1
# 601.0  SIGMA    20  19    20  18    18  19      1
# Name: count, Length: 599, dtype: int64

# %%
df.columns
# Out:
# Index(['S.NO', 'SECTION', 'DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     601 non-null    float64
#  1   SECTION  691 non-null    object
#  2   DV       716 non-null    object
#  3   M-II     716 non-null    object
#  4   PP       716 non-null    object
#  5   BEEE     716 non-null    object
#  6   FL       715 non-null    object
#  7   FIMS     716 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 45.0+ KB

# %%
df['S.NO'] = range(1, len(df) + 1)
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   714    ZETA  19    8   8   19  17   18
# 714   715    ZETA  12    1   7   10  20    8
# 715   716    ZETA  17    6  14   14  17   18
# 716   717    ZETA  12    1   6    7  15   12
# 717   718    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     718 non-null    int64
#  1   SECTION  691 non-null    object
#  2   DV       716 non-null    object
#  3   M-II     716 non-null    object
#  4   PP       716 non-null    object
#  5   BEEE     716 non-null    object
#  6   FL       715 non-null    object
#  7   FIMS     716 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 45.0+ KB

# %%
df.head()
# Out:
#    S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1   ALPHA  12    0  17    9  19   15
# 1     2   ALPHA  19   12  16   16  18    3
# 2     3   ALPHA  18   14  18   18  18   16
# 3     4   ALPHA  15    9  19   17  19   15
# 4     5   ALPHA  18   17  19   19  20   18

# %%
df['FL'] = df['FL'].fillna(0) 
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 690 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     690 non-null    int64
#  1   SECTION  690 non-null    object
#  2   DV       690 non-null    object
#  3   M-II     690 non-null    object
#  4   PP       690 non-null    object
#  5   BEEE     690 non-null    object
#  6   FL       690 non-null    object
#  7   FIMS     690 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 48.5+ KB

# %%
df.fillna(0)
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   714    ZETA  19    8   8   19  17   18
# 714   715    ZETA  12    1   7   10  20    8
# 715   716    ZETA  17    6  14   14  17   18
# 716   717    ZETA  12    1   6    7  15   12
# 717   718    ZETA  19   14  17   16  20   19
#
# [690 rows x 8 columns]

# %%
print(df['S.NO'].dtypes)
# Out:
# int64

# %%
columns_to_drop = [col for col in  df.columns]

# %%
columns_to_drop
# Out:
# ['S.NO', 'SECTION', 'DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']

# %%
df.fillna(0,inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3188\1840858203.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(0,inplace=True)

# %%
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   714    ZETA  19    8   8   19  17   18
# 714   715    ZETA  12    1   7   10  20    8
# 715   716    ZETA  17    6  14   14  17   18
# 716   717    ZETA  12    1   6    7  15   12
# 717   718    ZETA  19   14  17   16  20   19
#
# [690 rows x 8 columns]

# %%
df.plot()
plt.show()

# %%
df.columns
# Out:
# Index(['S.NO', 'SECTION', 'DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS'], dtype='object')

# %%
columns_to_convert = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
for column in columns_to_convert:
    df[column] = pd.to_numeric(df[column], errors='coerce').fillna(0)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3188\2572407181.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').fillna(0)

# %%
df.SECTION.count
# Out:
# <bound method Series.count of 0      ALPHA
# 1      ALPHA
# 2      ALPHA
# 3      ALPHA
# 4      ALPHA
#        ...
# 713     ZETA
# 714     ZETA
# 715     ZETA
# 716     ZETA
# 717     ZETA
# Name: SECTION, Length: 690, dtype: object>

# %%
df.SECTION.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      ALPHA
# 1      ALPHA
# 2      ALPHA
# 3      ALPHA
# 4      ALPHA
#        ...
# 713     ZETA
# 714     ZETA
# 715     ZETA
# 716     ZETA
# 717     ZETA
# Name: SECTION, Length: 690, dtype: object>

# %%
df.DV.value_counts()
# Out:
# DV
# 20.0    94
# 17.0    78
# 16.0    72
# 18.0    66
# 15.0    60
# 19.0    58
# 11.0    42
# 14.0    40
# 12.0    39
# 13.0    30
# 10.0    25
# 9.0     20
# 6.0     12
# 5.0     11
# 8.0     11
# 0.0     11
# 7.0      8
# 2.0      5
# 4.0      4
# 1.0      3
# 3.0      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,9))
sns.histplot(df['DV'], bins=12,color='yellow')
plt.title('Histogram  of Marks in DV', fontsize=16)
plt.xlabel('Marks in DV', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.show()

# %% [markdown]
# The histogram of marks in the subject 'DV'. Peaks in the histogram indicate the marks ranges most  students achieved.

# %%
plt.figure(figsize=(9,7))
sns.histplot(df['M-II'], bins=8,color='pink')
plt.title('Histogram  of Marks in M-II', fontsize=16)
plt.xlabel('Marks in M-II', fontsize=13)
plt.ylabel('Frequency', fontsize=13)
plt.show()

# %% [markdown]
# The histogram of marks in the subject 'M-11'.Peaks in the histogram indicate the marks ranges most students achieved.

# %%
plt.figure(figsize=(9,9))
sns.histplot(df['PP'], bins=11,color='gray')
plt.title('Histogram of Marks in PP', fontsize=16)
plt.xlabel('Marks in PP', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.show()

# %% [markdown]
# The histogram of marks in the subject 'PP'.Peaks in the histogram indicate the marks ranges most students achieved.

# %%
plt.figure(figsize=(8, 8))
sns.histplot(df['BEEE'], bins=14,color='blue')
plt.title('Histogram of Marks in BEEE', fontsize=16)
plt.xlabel('Marks in BEEE', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.show()

# %% [markdown]
# The histogram of marks in the subject 'BEEE'.Peaks in the histogram indicate the marks ranges most students achieved.

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['FL'], bins=10,color='black')
plt.title('Histogram of Marks in FL', fontsize=16)
plt.xlabel('Marks in FL', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %% [markdown]
# The histogram of marks in the subject 'FL'.Peaks in the histogram indicate the marks ranges most students achieved.

# %%
plt.figure(figsize=(7,7))
sns.histplot(df['FIMS'], bins=10,color='purple')
plt.title('Histogram of Marks in FIMS', fontsize=16)
plt.xlabel('Marks in FIMS', fontsize=8)
plt.ylabel('Frequency', fontsize=8)
plt.show()

# %% [markdown]
# The histogram of marks in the subject 'FIMS'.Peaks in the histogram indicate the marks ranges most students achieved.

# %%
col = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']

# %% [markdown]
# Difining the no of colunms

# %%
df[col] = df[col].apply(pd.to_numeric, errors='coerce')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18520\1423930895.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# Appling the seaborn lib

# %%
df[col] = df[col].fillna(0)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18520\3291156155.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].fillna(0)

# %%
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...
# 474   475   SIGMA  11.0   4.0   2.0   2.0   8.0  10.0
# 475   476   SIGMA  18.0   2.0  12.0   3.0  17.0  15.0
# 476   477   SIGMA  20.0   6.0  16.0  11.0  20.0  14.0
# 478   479   SIGMA  20.0  20.0   5.0  19.0  18.0  14.0
# 479   480   SIGMA  20.0  16.0  18.0  19.0  20.0  19.0
#
# [474 rows x 8 columns]

# %%
df['TOTAL'] = df[col].sum(axis=1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18520\1326692810.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TOTAL'] = df[col].sum(axis=1)

# %%
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...
# 474   475   SIGMA  11.0   4.0   2.0   2.0   8.0  10.0   37.0
# 475   476   SIGMA  18.0   2.0  12.0   3.0  17.0  15.0   67.0
# 476   477   SIGMA  20.0   6.0  16.0  11.0  20.0  14.0   87.0
# 478   479   SIGMA  20.0  20.0   5.0  19.0  18.0  14.0   96.0
# 479   480   SIGMA  20.0  16.0  18.0  19.0  20.0  19.0  112.0
#
# [474 rows x 9 columns]

# %%
df.TOTAL.tail(10)
# Out:
# 469     14.0
# 470     84.0
# 471    120.0
# 472    117.0
# 473    120.0
# 474     37.0
# 475     67.0
# 476     87.0
# 478     96.0
# 479    112.0
# Name: TOTAL, dtype: float64

# %%
df.head(10)
# Out:
#    S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL
# 0     1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0
# 1     2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0
# 2     3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0
# 3     4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0
# 4     5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0
# 5     6   ALPHA  17.0  16.0  18.0  10.0  15.0   9.0   85.0
# 6     7   ALPHA  15.0  10.0  20.0  20.0  15.0  14.0   94.0
# 7     8   ALPHA  17.0  17.0  19.0  20.0  19.0  13.0  105.0
# 8     9   ALPHA  10.0  18.0   0.0  20.0  19.0  15.0   82.0
# 9    10   ALPHA  18.0  19.0  20.0  20.0  20.0  15.0  112.0

# %%
plt.figure(figsize=[6,9])
plt.hist(df['TOTAL'], color='black', bins=10, edgecolor='black')
plt.title("Histogram of Total Marks")
plt.xlabel("Total Marks")
plt.ylabel("Number of Students")
plt.show()

# %% [markdown]
# Histogram of total marks

# %%
col = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
sub = df[col].mean()

# %%
sub
# Out:
# DV      14.405063
# M-II    10.113924
# PP      12.875527
# BEEE    13.289030
# FL      15.523207
# FIMS    13.632911
# dtype: float64

# %% [markdown]
# No.of Subject

# %%
plt.figure(figsize=(10, 6))
sub.plot(kind='bar', color='green')
plt.title('Average Marks per Subject', fontsize=10)
plt.xlabel('Subjects', fontsize=10)
plt.ylabel('Average Marks', fontsize=10)
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Average marks each subject

# %%
average_total_by_section = df.groupby('SECTION')['TOTAL'].mean()
plt.figure(figsize=[8,8])
average_total_by_section.plot(kind='bar', color='red', edgecolor='black')
plt.title(" Section Average Total Marks")
plt.xlabel("Section")
plt.ylabel("Average Total Marks")
plt.show()

# %% [markdown]
# Average of total marks in each section

# %%
avg = df[['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']].mean().idxmax()
plt.figure(figsize=(9,9))
sns.histplot(df[avg], bins=10, color='blue')
plt.title(f'Histogram of Marks in {avg}', fontsize=20)
plt.xlabel(f'Marks in {avg}', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.show()

# %% [markdown]
# Histogram of marks in FL subject

# %%
df['Total'] = df[['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']].sum(axis=1)
subjectmax = 100
subjectsnum = len(['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS'])
totalmarks = subjectmax * subjectsnum
df['Percentage'] = (df['Total'] / totalmarks) * 100
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18520\2250639286.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total'] = df[['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']].sum(axis=1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_18520\2250639286.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Percentage'] = (df['Total'] / totalmarks) * 100

# %% [markdown]
# Percentage of all maks

# %%
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0   72.0
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0   84.0
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0  102.0
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0   94.0
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 474   475   SIGMA  11.0   4.0   2.0   2.0   8.0  10.0   37.0   37.0
# 475   476   SIGMA  18.0   2.0  12.0   3.0  17.0  15.0   67.0   67.0
# 476   477   SIGMA  20.0   6.0  16.0  11.0  20.0  14.0   87.0   87.0
# 478   479   SIGMA  20.0  20.0   5.0  19.0  18.0  14.0   96.0   96.0
# 479   480   SIGMA  20.0  16.0  18.0  19.0  20.0  19.0  112.0  112.0
#
#      Percentage
# 0     12.000000
# 1     14.000000
# 2     17.000000
# 3     15.666667
# 4     18.500000
# ..          ...
# 474    6.166667
# ...

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Percentage'], bins=10, color='violet')
plt.title('Histogram of Percentages', fontsize=15)
plt.xlabel('Percentage', fontsize=20)
plt.ylabel('Frequency', fontsize=20)
plt.show()

# %% [markdown]
# Histogram of Percentages

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Total', y='Percentage', color='red', s=10)
plt.title('Relationship Between Total Marks and Percentage', fontsize=16)
plt.xlabel('Total Marks')
plt.ylabel('Percentage')
plt.show()

# %% [markdown]
# Relationship Between Total Marks and Percentage.

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='DV', y='M-II', color='teal')
plt.title('Scatter Plot of Marks: DV vs M-II', fontsize=16)
plt.xlabel('Marks in DV', fontsize=12)
plt.ylabel('Marks in M-II', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# Scatter Plot of Marks: DV vs M-II.Plot shows the correlation between marks in these two subjects.

# %%
plt.figure(figsize=[8, 6])
plt.scatter(df['TOTAL'], df['BEEE'], color='black', edgecolor='black')
plt.title("Scatter Plot: Total Marks vs BEEE Marks")
plt.xlabel("Total Marks")
plt.ylabel("BEEE Marks")
plt.show()

# %% [markdown]
# Plot shows the correlation between marks in these two subjects relationship Between Marks in total Marks vs BEEE Marks.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='PP', y='BEEE', color='skyblue', s=100)
plt.title('Relationship Between Marks in PP and BEEE', fontsize=16)
plt.xlabel('Marks in PP', fontsize=12)
plt.ylabel('Marks in BEEE', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# Plot shows the correlation between marks in these two subjects relationship Between Marks in PP and BEEE.

# %%
df.boxplot(by='DV', column =['TOTAL'], grid = False,color='brown',figsize=[5,6])
plt.title("Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Many of the marks of DV in this range got marks between 01  and 20, the maximum mark is 20 and minimum mark i and 0.

# %%
df.boxplot(by='M-II', column =['TOTAL'], grid = False,color='blue',figsize=[5,6])
plt.title("Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# Many of the marks of M-II in this range got marks between 01  and 20, the maximum mark is 20 and minimum mark i and 0.

# %%
df.boxplot(by='PP', column =['TOTAL'], grid = False,color='yellow',figsize=[5,6])
plt.title("Marks")
plt.ylabel("Total")
plt.show()

# %%
plt.figure(figsize=[8, 6])
average_total_by_section.plot(kind='pie', autopct='%1.1f%%', colors=['teal', 'blue', 'orange', 'red', 'violet', 'lime'])
plt.title("Subject-wise Average Scores")
plt.ylabel('subject')
plt.show()

# %% [markdown]
# This pie chart represents according to the Subject Average Scores in subject.

# %%
plt.figure(figsize=[8, 6])
average_total_by_section.plot(kind='pie', autopct='%1.1f%%', colors=['cyan', 'magenta', 'lime', 'gold', 'violet', 'darkorange'])
plt.title("Subject-wise Average Scores")
plt.ylabel('subject')
plt.show()

# %% [markdown]
# This pie chart represents according to the Subject Average Scores in section wise.

# %%
df.SECTION.count
# Out:
# <bound method Series.count of 0      ALPHA
# 1      ALPHA
# 2      ALPHA
# 3      ALPHA
# 4      ALPHA
#        ...
# 474    SIGMA
# 475    SIGMA
# 476    SIGMA
# 478    SIGMA
# 479    SIGMA
# Name: SECTION, Length: 474, dtype: object>

# %%
df= df.loc[df.groupby('SECTION')['TOTAL'].idxmax()]
print(df)
# Out:
#      S.NO  SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  Total  \
# 23     24    ALPHA  20.0  20.0  20.0  20.0  20.0  18.0  118.0  118.0
# 69     70     BETA  20.0  20.0  20.0  19.0  20.0  18.0  117.0  117.0
# 164   165    DELTA  20.0  20.0  20.0  20.0  20.0  18.0  118.0  118.0
# 217   218  EPSILON  20.0  20.0  20.0  19.0  20.0  20.0  119.0  119.0
# 273   274    GAMMA  18.0  20.0  16.0  20.0  20.0  19.0  113.0  113.0
# 406   407    OMEGA  20.0  20.0  20.0  20.0  20.0  18.0  118.0  118.0
# 471   472    SIGMA  20.0  20.0  20.0  20.0  20.0  20.0  120.0  120.0
# 367   368     ZETA  20.0  20.0  19.0  20.0  18.0  16.0  113.0  113.0
#
#      Percentage
# 23    19.666667
# 69    19.500000
# 164   19.666667
# 217   19.833333
# 273   18.833333
# 406   19.666667
# 471   20.000000
# 367   18.833333

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df= df[df['SECTION'] == 'ALPHA'].sort_values(by='Total', ascending=False).iloc[0]
print(df)
# Out:
# S.NO                 24
# SECTION           ALPHA
# DV                 20.0
# M-II               20.0
# PP                 20.0
# BEEE               20.0
# FL                 20.0
# FIMS               18.0
# TOTAL             118.0
# Total             118.0
# Percentage    19.666667
# Name: 23, dtype: object

# %%
print(type(df))
# Out:
# <class 'pandas.core.series.Series'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_excel("MIDMARKS.xlsx")

# %%
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df.fillna(0)
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   0.0    ZETA  19    8   8   19  17   18
# 714   0.0    ZETA  12    1   7   10  20    8
# 715   0.0    ZETA  17    6  14   14  17   18
# 716   0.0    ZETA  12    1   6    7  15   12
# 717   0.0    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['S.NO', 'SECTION', 'DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS'], dtype='object')

# %%
columns_to_sum = ['S.NO','DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
df[columns_to_sum] = df[columns_to_sum].apply(pd.to_numeric, errors='coerce')

# %%
df[columns_to_sum] = df[columns_to_sum].fillna(0)

# %%
df['Total'] = df[columns_to_sum].sum(axis=1)

# %%
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   73.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   86.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  105.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   98.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  116.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0
#
# [718 rows x 9 columns]

# %%
sns.lineplot(x='DV', y='Total', data=df)
plt.title('Line Plot of DV vs Total')
plt.show()

# %% [markdown]
# Line plot of DV and Total

# %%
sns.lineplot(x='SECTION', y='Total', data=df)
plt.title('Line Plot of SECTION vs Total')
plt.show()

# %%
sns.relplot(data=df, x="Total", y="SECTION", hue="FIMS")

# %%
sns.relplot(data=df, x="SECTION", y="DV", hue="FIMS", kind="line")

# %%
sns.relplot(data=df, x="DV", y="SECTION", hue="Total", kind="line")

# %%
sns.lineplot(x="SECTION", y="Total", data=df) 
sns.set_style("dark")
plt.show()

# %%
sns.lineplot(x="DV", y="Total", data=df) 
sns.despine()
plt.show()

# %%
plt.figure(figsize = (2, 4))
sns.lineplot(x="DV", y="SECTION", data=df)
# Out:
# <Axes: xlabel='DV', ylabel='SECTION'>

# %%
sns.set_context("paper",font_scale=1.02)
sns.lineplot(x="SECTION", y="DV", data=df)
# Out:
# <Axes: xlabel='SECTION', ylabel='DV'>

# %%
sns.lineplot(x="SECTION", y="FIMS", data=df) 
with sns.axes_style('darkgrid'):
          sns.lineplot(x="SECTION", y="FIMS", data=df)

# %%
sns.set_palette('Accent')
sns.lineplot(x="DV", y="SECTION", data=df)
# Out:
# <Axes: xlabel='DV', ylabel='SECTION'>

# %%
def graph():
    sns.lineplot(x="PP", y="Total", data=df)
plt.subplot(121)
graph()
plt.subplot(122)
graph()

# %%
df['BC'] = (df[['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']] < 10).sum(axis=1)
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  BC
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   73.0   2
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   86.0   1
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  105.0   0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   98.0   1
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  116.0   0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...  ..
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0   2
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   3
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0   1
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   3
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0   0
#
# [718 rows x 10 columns]

# %%
bc = []
for i in range(len(df)):
    count = 0
    if df.iloc[i]['DV'] < 10:
        count += 1
    if df.iloc[i]['M-II'] < 10:
        count += 1
    if df.iloc[i]['PP'] < 10:
        count += 1
    if df.iloc[i]['BEEE'] < 10:
        count += 1
    if df.iloc[i]['FL'] < 10:
        count += 1
    if df.iloc[i]['FIMS'] < 10:
        count += 1
    bc.append(count)

df['BC'] = bc
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  BC
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   73.0   2
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   86.0   1
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  105.0   0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   98.0   1
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  116.0   0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...  ..
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0   2
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   3
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0   1
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   3
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0   0
#
# [718 rows x 10 columns]

# %%
df.BC.value_counts()
# Out:
# BC
# 0    273
# 1    172
# 2    121
# 3     69
# 4     43
# 5     23
# 6     17
# Name: count, dtype: int64

# %%
print(df[['PP','BC']])
# Out:
#        PP  BC
# 0    17.0   2
# 1    16.0   1
# 2    18.0   0
# 3    19.0   1
# 4    19.0   0
# ..    ...  ..
# 713   8.0   2
# 714   7.0   3
# 715  14.0   1
# 716   6.0   3
# 717  17.0   0
#
# [718 rows x 2 columns]

# %%
sns.lineplot(x='BC', y='Total', data=df)
plt.title('Line Plot of BC vs Total')
plt.show()

# %%
sns.lineplot(x='SECTION', y='BC', data=df)
plt.title('Line Plot of DV vs BC')
plt.show()

# %%
sns.lineplot(x='SECTION', y='BC', data=df)
plt.title('Line Plot of SECTION vs BC')
plt.show()

# %%
sns.relplot(data=df, x="BC", y="SECTION", hue="FIMS")

# %%
sns.relplot(data=df, x="BC", y="SECTION", hue="Total", kind="line")

# %%
sns.lineplot(x="SECTION", y="BC", data=df) 
sns.set_style("dark")
plt.show()

# %%
plt.figure(figsize = (5,5))
sns.lineplot(x="SECTION", y="BC", data=df)
# Out:
# <Axes: xlabel='SECTION', ylabel='BC'>

# %%
sns.set_context("paper",font_scale=1.02)
sns.lineplot(x="SECTION", y="BC", data=df)
# Out:
# <Axes: xlabel='SECTION', ylabel='BC'>

# %%
sns.lineplot(x="SECTION", y="FIMS", data=df) 
with sns.axes_style('darkgrid'):
          sns.lineplot(x="FIMS", y="BC", data=df)

# %%
sns.set_palette('Accent')
sns.lineplot(x="SECTION", y="BC", data=df)
# Out:
# <Axes: xlabel='SECTION', ylabel='BC'>

# %%
def graph():
    sns.lineplot(x="PP", y="BC", data=df)
plt.subplot(121)
graph()
plt.subplot(122)
graph()

# %%
def graph():
    sns.lineplot(x="SECTION", y="BC", data=df)
plt.subplot(121)
graph()
plt.subplot(122)
graph()

# %%
plt.figure(figsize=[6,9])
plt.hist(df['BC'], color='black', bins=10, edgecolor='black')
plt.title("Histogram of BC Marks")
plt.xlabel("BC Marks")
plt.ylabel("Number of Students")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='DV', y='BC', color='teal')
plt.title('Scatter Plot of Marks: DV vs M-II', fontsize=16)
plt.xlabel('Marks in DV', fontsize=12)
plt.ylabel('Marks in BC', fontsize=12)
plt.grid(True)
plt.show()

# %%
df.boxplot(by='SECTION', column =['BC'], grid = False,color='blue',figsize=[5,6])
plt.title("BC Marks")
plt.ylabel("SECTION")
plt.show()

# %%
plt.figure(figsize=[8, 6])
average_total_by_section.plot(kind='pie', autopct='%1.1f%%', colors=['cyan', 'magenta', 'lime', 'gold', 'violet', 'darkorange'])
plt.title("BC")
plt.ylabel('SECTION')
plt.show()

# %%
df['Programming skills'] = (df[['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']] < 10).sum(axis=1)
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  BC  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   73.0   2
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   86.0   1
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  105.0   0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   98.0   1
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  116.0   0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...  ..
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0   2
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   3
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0   1
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   3
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0   0
#
#      Programming skills
# 0                     2
# 1                     1
# 2                     0
# 3                     1
# 4                     0
# ..                  ...
# ...

# %%
def assign_grade(PP):
    if PP >=18 :
        return "very good"
        
    elif PP >=15 :
        return 'good'
    elif PP >= 13:
        return 'average'
    else:
        return 'poor'
df['Programming skills'] = df['PP'].apply(assign_grade)
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  BC  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   73.0   2
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   86.0   1
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  105.0   0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   98.0   1
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  116.0   0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...  ..
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0   2
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   3
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0   1
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   3
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0   0
#
#     Programming skills
# 0                 good
# 1                 good
# 2            very good
# 3            very good
# 4            very good
# ..                 ...
# ...

# %%
sns.lineplot(x='Programming skills', y='PP', data=df)
plt.title('Line Plot of Programming skills vs PP')
plt.show()

# %%
df['DV Skills'] = (df[['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']] < 10).sum(axis=1)
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  BC  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   73.0   2
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   86.0   1
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  105.0   0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   98.0   1
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  116.0   0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...  ..
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0   2
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   3
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0   1
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   3
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0   0
#
#     Programming skills  DV Skills
# 0                 good          2
# 1                 good          1
# 2            very good          0
# 3            very good          1
# ...

# %%
def assign_grade(DV):
    if DV >=18 :
        return "very good"
        
    elif DV >=15 :
        return 'good'
    elif DV >= 13:
        return 'average'
    else:
        return 'poor'
df['DV skills'] = df['DV'].apply(assign_grade)
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  BC  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   73.0   2
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   86.0   1
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  105.0   0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   98.0   1
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  116.0   0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...  ..
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0   2
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   3
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0   1
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   3
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0   0
#
#     Programming skills  DV Skills  DV skills
# 0                 good          2       poor
# 1                 good          1  very good
# 2            very good          0  very good
# ...

# %%
sns.lineplot(x='DV skills', y='DV', data=df)
plt.title('Line Plot of Programming skills vs DV')
plt.show()

# %%
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  BC  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   73.0   2
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   86.0   1
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  105.0   0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   98.0   1
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  116.0   0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...  ..
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0   2
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   3
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0   1
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   3
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0   0
#
#     Programming skills  DV Skills  DV skills
# 0                 good          2       poor
# 1                 good          1  very good
# 2            very good          0  very good
# ...

# %%
subjects = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
subset = df[df[subjects].eq(20).any(axis=1)]
print("Subset of students who scored 20 in any subject:")
print(subset)
for subject in subjects:
    count_20 = (df[subject] == 20).sum()
    print(f"Students who scored 20 in {subject}: {count_20}")
# Out:
# Subset of students who scored 20 in any subject:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  BC  \
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  116.0   0
# 6     7.0   ALPHA  15.0  10.0  20.0  20.0  15.0  14.0  101.0   0
# 7     8.0   ALPHA  17.0  17.0  19.0  20.0  19.0  13.0  113.0   0
# 8     9.0   ALPHA  10.0  18.0   0.0  20.0  19.0  15.0   91.0   1
# 9    10.0   ALPHA  18.0  19.0  20.0  20.0  20.0  15.0  122.0   0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...  ..
# 705   0.0    ZETA  16.0   0.0  11.0  16.0  20.0   0.0   63.0   2
# 709   0.0    ZETA  19.0  17.0  12.0  17.0  20.0  16.0  101.0   0
# 711   0.0    ZETA  18.0   9.0  12.0  20.0  16.0  16.0   91.0   1
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   3
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0   0
#
#     Programming skills  DV Skills  DV skills
# 4            very good          0  very good
# ...

# %%
plt.figure(figsize=[8, 6])
average_total_by_section.plot(kind='pie', autopct='%1.1f%%', colors=['cyan', 'magenta', 'lime', 'gold', 'violet', 'darkorange'])
plt.title("Programming skills on Subject")
plt.ylabel('Programming skills')
plt.show()

# %%
df.describe()
# Out:
#              S.NO          DV        M-II          PP        BEEE          FL  \
# count  718.000000  718.000000  718.000000  718.000000  718.000000  718.000000
# mean   251.951253   14.746518    9.922006   12.733983   13.250696   15.501393
# std    193.921102    4.629339    6.610886    5.848171    5.817407    4.544449
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     63.250000   12.000000    4.000000    9.000000    9.000000   13.000000
# 50%    242.500000   16.000000   10.000000   14.000000   15.000000   16.000000
# 75%    421.750000   18.000000   16.000000   18.000000   18.000000   20.000000
# max    601.000000   20.000000   20.000000   20.000000   20.000000   20.000000
#
#              FIMS       Total          BC   DV Skills
# count  718.000000  718.000000  718.000000  718.000000
# mean    14.008357  332.114206    1.406685    1.406685
# std      4.761238  196.082514    1.553889    1.553889
# ...

# %%
plt.figure(figsize=[8, 6])
average_total_by_section.plot(kind='pie', autopct='%1.1f%%', colors=['cyan', 'magenta', 'lime', 'gold', 'violet', 'darkorange'])
plt.title("DV skills on Section")
plt.ylabel('DV Skills')
plt.show()

# %%
grade_counts_students = df['DV Skills'].value_counts()

plt.figure(figsize=(6,6))
grade_counts_students.plot.pie(autopct='%1.1f%%', startangle=90, colors=['yellow', 'orange', 'green', 'pink'])
plt.title(' Programming Skills ')
plt.ylabel('PP')  
plt.show()

# %%
grade_counts_students = df['DV Skills'].value_counts()

plt.figure(figsize=(6,6))
grade_counts_students.plot.pie(autopct='%1.1f%%', startangle=90, colors=['yellow', 'orange', 'green', 'pink'])
plt.title('DV')
plt.ylabel('PP')  
plt.show()

# %%
grade_counts_students = df['DV Skills'].value_counts()

plt.figure(figsize=(6,6))
grade_counts_students.plot.pie(autopct='%1.1f%%', startangle=90, colors=['yellow', 'orange', 'green', 'pink'])
plt.title('DV')
plt.ylabel('DV Skills')  
plt.show()

# %%
grade_counts_students = df['Programming skills'].value_counts()

plt.figure(figsize=(6,6))
grade_counts_students.plot.pie(autopct='%1.1f%%', startangle=90, colors=['yellow', 'orange', 'green', 'pink'])
plt.title('PP')
plt.ylabel('PP')  
plt.show()

# %%
grade_counts_students = df['DV Skills'].value_counts()

plt.figure(figsize=(6,6))
grade_counts_students.plot.pie(autopct='%1.1f%%', startangle=90, colors=['yellow', 'orange', 'green', 'pink'])
plt.title('Programming skills')
plt.ylabel('DV Skills')  
plt.show()

# %%
df.Total.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       73.0
# 1       86.0
# 2      105.0
# 3       98.0
# 4      116.0
#        ...
# 713     89.0
# 714     58.0
# 715     86.0
# 716     53.0
# 717    105.0
# Name: Total, Length: 718, dtype: float64>

# %%
df.columns
# Out:
# Index(['S.NO', 'SECTION', 'DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS', 'Total',
#        'BC', 'Programming skills', 'DV Skills', 'DV skills'],
#       dtype='object')

# %%
grade_counts_students = df['Programming skills'].value_counts()

plt.figure(figsize=(6,6))
grade_counts_students.plot.pie(autopct='%1.1f%%', startangle=90, colors=['yellow', 'orange', 'green', 'pink'])
plt.title('Programming skills of student')
plt.ylabel('')  
plt.show()

# %%
D=(df['DV']<10)&(df['SECTION']=='DELTA')
D.value_counts()
# Out:
# False    704
# True      14
# Name: count, dtype: int64

# %%
D=(df['DV']<10)&(df['SECTION']=='ALPHA')
D.value_counts()
# Out:
# False    701
# True      17
# Name: count, dtype: int64

# %%
D=(df['PP']<10)&(df['SECTION']=='ALPHA')
D.value_counts()
# Out:
# False    706
# True      12
# Name: count, dtype: int64

# %%
D=(df['M-II']<10)&(df['SECTION']=='ALPHA')
D.value_counts()
# Out:
# False    700
# True      18
# Name: count, dtype: int64

# %%
D=(df['FIMS']<10)&(df['SECTION']=='ALPHA')
D.value_counts()
# Out:
# False    696
# True      22
# Name: count, dtype: int64

# %%
D=(df['FL']<10)&(df['SECTION']=='ALPHA')
D.value_counts()
# Out:
# False    717
# True       1
# Name: count, dtype: int64

# %%
D=(df['BEEE']<10)&(df['SECTION']=='ALPHA')
D.value_counts()
# Out:
# False    710
# True       8
# Name: count, dtype: int64

# %%
D=(df['PP']<10)&(df['SECTION']=='DELTA')
D.value_counts()
# Out:
# False    690
# True      28
# Name: count, dtype: int64

# %%
D=(df['M-II']<10)&(df['SECTION']=='DELTA')
D.value_counts()
# Out:
# False    673
# True      45
# Name: count, dtype: int64

# %%
D=(df['FIMS']<10)&(df['SECTION']=='DELTA')
D.value_counts()
# Out:
# False    714
# True       4
# Name: count, dtype: int64

# %%
D=(df['FL']<10)&(df['SECTION']=='DELTA')
D.value_counts()
# Out:
# False    717
# True       1
# Name: count, dtype: int64

# %%
D=(df['BEEE']<10)&(df['SECTION']=='DELTA')
D.value_counts()
# Out:
# False    672
# True      46
# Name: count, dtype: int64

# %%
D=(df['BEEE']<10)&(df['SECTION']=='ZETA')
D.value_counts()
# Out:
# False    700
# True      18
# Name: count, dtype: int64

# %%
D=(df['PP']<10)&(df['SECTION']=='ZETA')
D.value_counts()
# Out:
# False    668
# True      50
# Name: count, dtype: int64

# %%
D=(df['FIMS']<10)&(df['SECTION']=='ZETA')
D.value_counts()
# Out:
# False    698
# True      20
# Name: count, dtype: int64

# %%
D=(df['FL']<10)&(df['SECTION']=='ZETA')
D.value_counts()
# Out:
# False    703
# True      15
# Name: count, dtype: int64

# %%
D=(df['M-II']<10)&(df['SECTION']=='ZETA')
D.value_counts()
# Out:
# False    655
# True      63
# Name: count, dtype: int64

# %%
D=(df['DV']<10)&(df['SECTION']=='ZETA')
D.value_counts()
# Out:
# False    710
# True       8
# Name: count, dtype: int64

# %%
D=(df['M-II']<10)&(df['SECTION']=='BETA')
D.value_counts()
# Out:
# False    693
# True      25
# Name: count, dtype: int64

# %%
D=(df['DV']<10)&(df['SECTION']=='BETA')
D.value_counts()
# Out:
# False    701
# True      17
# Name: count, dtype: int64

# %%
D=(df['FL']<10)&(df['SECTION']=='BETA')
D.value_counts()
# Out:
# False    717
# True       1
# Name: count, dtype: int64

# %%
D=(df['FIMS']<10)&(df['SECTION']=='BETA')
D.value_counts()
# Out:
# False    707
# True      11
# Name: count, dtype: int64

# %%
D=(df['PP']<10)&(df['SECTION']=='BETA')
D.value_counts()
# Out:
# False    710
# True       8
# Name: count, dtype: int64

# %%
D=(df['BEEE']<10)&(df['SECTION']=='BETA')
D.value_counts()
# Out:
# False    677
# True      41
# Name: count, dtype: int64

# %%
D=(df['BEEE']<10)&(df['SECTION']=='GAMMA')
D.value_counts()
# Out:
# False    701
# True      17
# Name: count, dtype: int64

# %%
D=(df['PP']<10)&(df['SECTION']=='GAMMA')
D.value_counts()
# Out:
# False    682
# True      36
# Name: count, dtype: int64

# %%
D=(df['FIMS']<10)&(df['SECTION']=='GAMMA')
D.value_counts()
# Out:
# False    695
# True      23
# Name: count, dtype: int64

# %%
D=(df['FL']<10)&(df['SECTION']=='GAMMA')
D.value_counts()
# Out:
# False    716
# True       2
# Name: count, dtype: int64

# %%
D=(df['DV']<10)&(df['SECTION']=='GAMMA')
D.value_counts()
# Out:
# False    707
# True      11
# Name: count, dtype: int64

# %%
D=(df['M-II']<10)&(df['SECTION']=='GAMMA')
D.value_counts()
# Out:
# False    672
# True      46
# Name: count, dtype: int64

# %%
D=(df['M-II']<10)&(df['SECTION']=='SIGMA')
D.value_counts()
# Out:
# False    698
# True      20
# Name: count, dtype: int64

# %%
D=(df['DV']<10)&(df['SECTION']=='SIGMA')
D.value_counts()
# Out:
# False    712
# True       6
# Name: count, dtype: int64

# %%
D=(df['FL']<10)&(df['SECTION']=='SIGMA')
D.value_counts()
# Out:
# False    715
# True       3
# Name: count, dtype: int64

# %%
D=(df['FIMS']<10)&(df['SECTION']=='SIGMA')
D.value_counts()
# Out:
# False    710
# True       8
# Name: count, dtype: int64

# %%
D=(df['PP']<10)&(df['SECTION']=='SIGMA')
D.value_counts()
# Out:
# False    706
# True      12
# Name: count, dtype: int64

# %%
D=(df['BEEE']<10)&(df['SECTION']=='SIGMA')
D.value_counts()
# Out:
# False    701
# True      17
# Name: count, dtype: int64

# %%
D=(df['BEEE']<10)&(df['SECTION']=='OMEGA')
D.value_counts()
# Out:
# False    697
# True      21
# Name: count, dtype: int64

# %%
D=(df['PP']<10)&(df['SECTION']=='OMEGA')
D.value_counts()
# Out:
# False    702
# True      16
# Name: count, dtype: int64

# %%
D=(df['FIMS']<10)&(df['SECTION']=='OMEGA')
D.value_counts()
# Out:
# False    711
# True       7
# Name: count, dtype: int64

# %%
D=(df['FL']<10)&(df['SECTION']=='OMEGA')
D.value_counts()
# Out:
# False    706
# True      12
# Name: count, dtype: int64

# %%
D=(df['FL']<10)&(df['SECTION']=='OMEGA')
D.value_counts()
# Out:
# False    706
# True      12
# Name: count, dtype: int64

# %%
passing_threshold = 10
pass_count = df[df['DV'] >= passing_threshold].shape[0]

total_count = df.shape[0]
pass_probability = pass_count / total_count

print("Pass Probability:", pass_probability)
# Out:
# Pass Probability: 0.8760445682451253

# %%
passing_threshold = 10
pass_count = df[df['PP'] >= passing_threshold].shape[0]

total_count = df.shape[0]
pass_probability = pass_count / total_count

print("Pass Probability:", pass_probability)
# Out:
# Pass Probability: 0.7005571030640668

# %%
passing_threshold = 10
pass_count = df[df['FL'] >= passing_threshold].shape[0]

total_count = df.shape[0]
pass_probability = pass_count / total_count

print("Pass Probability:", pass_probability)
# Out:
# Pass Probability: 0.9387186629526463

# %%
passing_threshold = 10
pass_count = df[df['FIMS'] >= passing_threshold].shape[0]

total_count = df.shape[0]
pass_probability = pass_count / total_count

print("Pass Probability:", pass_probability)
# Out:
# Pass Probability: 0.8328690807799443

# %%
passing_threshold = 10
pass_count = df[df['M-II'] >= passing_threshold].shape[0]

total_count = df.shape[0]
pass_probability = pass_count / total_count

print("Pass Probability:", pass_probability)
# Out:
# Pass Probability: 0.5139275766016713

# %%
passing_threshold = 10
pass_count = df[df['BEEE'] >= passing_threshold].shape[0]

total_count = df.shape[0]
pass_probability = pass_count / total_count

print("Pass Probability:", pass_probability)
# Out:
# Pass Probability: 0.7311977715877437

# %%
import pandas as pd

k = pd.read_excel("MIDMARKS.xlsx")
for col in k.columns[2:]:
    k[col] = pd.to_numeric(k[col], errors='coerce')
passing_marks = 10
subject_section_pass = k.groupby('SECTION').apply(
    lambda df: (df.iloc[:, 2:] >= passing_marks).sum()
)
subject_section_fail = k.groupby('SECTION').apply(
    lambda df: (df.iloc[:, 2:] < passing_marks).sum()
)
total_students_per_section = k.groupby('SECTION').size()
prob_pass = subject_section_pass.div(total_students_per_section, axis=0)
prob_fail = subject_section_fail.div(total_students_per_section, axis=0)
print("Number of students passing each subject in each section:")
print(subject_section_pass)
print("\nNumber of students failing each subject in each section:")
print(subject_section_fail)
print("\nProbability of students passing each subject in each section:")
print(prob_pass)
print("\nProbability of students failing each subject in each section:")
print(prob_fail)
# Out:
# Number of students passing each subject in each section:
#          DV  M-II  PP  BEEE  FL  FIMS
# SECTION
# ALPHA    73    72  78    82  89    68
# BETA     73    65  82    49  89    79
# DELTA    76    45  62    44  89    86
# EPSILON  84    24  39    71  80    66
# GAMMA    79    44  54    73  88    67
# OMEGA    80    32  74    69  78    83
# SIGMA    57    43  51    46  60    55
# ZETA     82    27  40    72  75    70
#
# Number of students failing each subject in each section:
#          DV  M-II  PP  BEEE  FL  FIMS
# SECTION
# ALPHA    17    18  11     7   0    21
# BETA     17    25   7    40   0    11
# DELTA    12    43  27    44   0     2
# EPSILON   3    63  48    16   7    21
# GAMMA     8    43  33    14   0    19
# OMEGA     8    56  13    15   7     0
# SIGMA     3    17   8    14   0     3
# ZETA      7    61  48    16  14    17
#
# Probability of students passing each subject in each section:
#                DV      M-II        PP      BEEE        FL      FIMS
# ...

# %%
df[df["SECTION"]=="ALPHA"].mean
# Out:
# <bound method DataFrame.mean of     S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0      1   ALPHA  12    0  17    9  19   15
# 1      2   ALPHA  19   12  16   16  18    3
# 2      3   ALPHA  18   14  18   18  18   16
# 3      4   ALPHA  15    9  19   17  19   15
# 4      5   ALPHA  18   17  19   19  20   18
# ..   ...     ...  ..  ...  ..  ...  ..  ...
# 85    86   ALPHA   3    4  14   13  18   13
# 86    87   ALPHA  17   18  19   20  20   18
# 87    88   ALPHA  13   17  14   19  15   17
# 88    89   ALPHA   2   17   0    3  15    2
# 89    90   ALPHA  10    6  15   10  15   10
#
# [90 rows x 8 columns]>

# %%
df[df["SECTION"]=="ALPHA"].std
# Out:
# <bound method DataFrame.std of     S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0      1   ALPHA  12    0  17    9  19   15
# 1      2   ALPHA  19   12  16   16  18    3
# 2      3   ALPHA  18   14  18   18  18   16
# 3      4   ALPHA  15    9  19   17  19   15
# 4      5   ALPHA  18   17  19   19  20   18
# ..   ...     ...  ..  ...  ..  ...  ..  ...
# 85    86   ALPHA   3    4  14   13  18   13
# 86    87   ALPHA  17   18  19   20  20   18
# 87    88   ALPHA  13   17  14   19  15   17
# 88    89   ALPHA   2   17   0    3  15    2
# 89    90   ALPHA  10    6  15   10  15   10
#
# [90 rows x 8 columns]>

# %%
df[df["SECTION"]=="ALPHA"].mean(numeric_only=True)
# Out:
# S.NO    45.5
# dtype: float64

# %%
df[df["SECTION"]=="ALPHA"].std(numeric_only=True)
# Out:
# S.NO    26.124701
# dtype: float64

# %%
df.shape
# Out:
# (716, 8)

# %%
df['SECTION'] = df['SECTION'].fillna('SIGMA') 
df['SECTION'] = df['SECTION'].replace('', 'SIGMA')
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11192\1840477511.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SECTION'] = df['SECTION'].fillna('SIGMA')
# C:\Users\HP\AppData\Local\Temp\ipykernel_11192\1840477511.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SECTION'] = df['SECTION'].replace('', 'SIGMA')
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# ...

# %%
df['S.NO'] = range(1, len(df) + 1)
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11192\1412173193.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['S.NO'] = range(1, len(df) + 1)
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   712    ZETA  19    8   8   19  17   18
# 714   713    ZETA  12    1   7   10  20    8
# 715   714    ZETA  17    6  14   14  17   18
# 716   715    ZETA  12    1   6    7  15   12
# 717   716    ZETA  19   14  17   16  20   19
#
# [716 rows x 8 columns]

# %%
df['FL'] = df['FL'].fillna(0) 
df=df.dropna()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11192\67764906.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FL'] = df['FL'].fillna(0)

# %%
df.shape
# Out:
# (716, 8)

# %%
df.info
# Out:
# <bound method DataFrame.info of      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   712    ZETA  19    8   8   19  17   18
# 714   713    ZETA  12    1   7   10  20    8
# 715   714    ZETA  17    6  14   14  17   18
# 716   715    ZETA  12    1   6    7  15   12
# 717   716    ZETA  19   14  17   16  20   19
#
# [716 rows x 8 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 716 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     716 non-null    int64
#  1   SECTION  716 non-null    object
#  2   DV       716 non-null    object
#  3   M-II     716 non-null    object
#  4   PP       716 non-null    object
#  5   BEEE     716 non-null    object
#  6   FL       716 non-null    object
#  7   FIMS     716 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 50.3+ KB

# %%
import pandas as pd
from scipy.stats import ttest_ind

# %%
df.head()
# Out:
#    S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1   ALPHA  12    0  17    9  19   15
# 1     2   ALPHA  19   12  16   16  18    3
# 2     3   ALPHA  18   14  18   18  18   16
# 3     4   ALPHA  15    9  19   17  19   15
# 4     5   ALPHA  18   17  19   19  20   18

# %%
df[df["SECTION"]=="ALPHA"]["DV"]
# Out:
# 0     12
# 1     19
# 2     18
# 3     15
# 4     18
#       ..
# 85     3
# 86    17
# 87    13
# 88     2
# 89    10
# Name: DV, Length: 90, dtype: object

# %%
df[df["SECTION"]=="ALPHA"]["DV"]
# Out:
# 0     12
# 1     19
# 2     18
# 3     15
# 4     18
#       ..
# 85     3
# 86    17
# 87    13
# 88     2
# 89    10
# Name: DV, Length: 90, dtype: object

# %%
df[df["SECTION"]=="BETA"]["DV"]
# Out:
# 90     17
# 91     14
# 92     11
# 93     14
# 94     12
#        ..
# 175    14
# 176     6
# 177    12
# 178    16
# 179    15
# Name: DV, Length: 90, dtype: object

# %%
from scipy.stats import ttest_ind
df[df['SECTION'] == 'ALPHA']['DV']
# Out:
# 0     12
# 1     19
# 2     18
# 3     15
# 4     18
#       ..
# 85     3
# 86    17
# 87    13
# 88     2
# 89    10
# Name: DV, Length: 90, dtype: object

# %%
df[df['SECTION'] == 'BETA']['DV']
# Out:
# 90     17
# 91     14
# 92     11
# 93     14
# 94     12
#        ..
# 175    14
# 176     6
# 177    12
# 178    16
# 179    15
# Name: DV, Length: 90, dtype: object

# %%
from scipy.stats import ttest_rel
ttest_rel(df[df['SECTION'] == 'ALPHA']['DV'] , df[df['SECTION'] == 'BETA']['DV'])
# Out:
# TtestResult(statistic=0.6677896583545824, pvalue=0.5059958752914141, df=89)

# %%
from scipy.stats import ttest_rel

# %%
ttest_rel(df[df['SECTION'] == 'ALPHA']['DV'], df[df['SECTION'] == 'BETA']['DV'])
# Out:
# TtestResult(statistic=0.6677896583545824, pvalue=0.5059958752914141, df=89)

# %%
df.columns
# Out:
# Index(['S.NO', 'SECTION', 'DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS'], dtype='object')

# %%
from scipy.stats import ttest_rel

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 716 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     716 non-null    int64
#  1   SECTION  716 non-null    object
#  2   DV       716 non-null    object
#  3   M-II     716 non-null    object
#  4   PP       716 non-null    object
#  5   BEEE     716 non-null    object
#  6   FL       716 non-null    object
#  7   FIMS     716 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 50.3+ KB
